# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17483, done.
# remote: Total 17483 (delta 0), reused 0 (delta 0), pack-reused 17483 (from 1)
# Receiving objects: 100% (17483/17483), 16.55 MiB | 17.86 MiB/s, done.
# Resolving deltas: 100% (11995/11995), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 129.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# !ls "/content/drive/MyDrive/ColabDataset"
# Out:
#  ColabDataset  'Colab Notebooks'   MorseCode.gdoc  'Untitled document.gdoc'
# 'Skin Problems Detection.v1i.yolov5pytorch.zip'

# %%
# !unzip "/content/drive/MyDrive/ColabDataset/Skin Problems Detection.v1i.yolov5pytorch.zip" -d /content/skin_dataset
# Out:
# Archive:  /content/drive/MyDrive/ColabDataset/Skin Problems Detection.v1i.yolov5pytorch.zip
#   inflating: /content/skin_dataset/README.dataset.txt
#   inflating: /content/skin_dataset/README.roboflow.txt
#   inflating: /content/skin_dataset/data.yaml
#    creating: /content/skin_dataset/test/
#    creating: /content/skin_dataset/test/images/
#  extracting: /content/skin_dataset/test/images/01F3MMVYT4SJ23G9XQQ3S8BKNE_jpeg.rf.4e383348d37e89ea988f564a2f8f9ed5.jpg
#  extracting: /content/skin_dataset/test/images/01F3MMW28Z2J8R32ZE4BECFRS8_jpeg.rf.b9e493c1cd94d647bcf89a568b420563.jpg
#  extracting: /content/skin_dataset/test/images/01F3MMWVX2Z9ZE1Z0Y3R4JA8B5_jpeg.rf.864aa4d58ddbd7d50c7df8b4d7f4216c.jpg
#  extracting: /content/skin_dataset/test/images/01F3MMX1JKX31TSGA6GK7S16T1_jpeg.rf.c886c48ecc45b3893b52185bd365e643.jpg
#  extracting: /content/skin_dataset/test/images/01F3MMX2RXFSJV79X3QMF6XXW8_jpeg.rf.dabdf33b978ca04f165f3dffb2819d37.jpg
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 20 --data /content/skin_dataset/data.yaml --weights yolov5s.pt --name skin_detection
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-28 15:07:40.071160: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748444860.327861    4487 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
yaml_content = """
train: /content/skin_dataset/train/images
val: /content/skin_dataset/valid/images

nc: 12
names:  ['Dark Circle', 'Melasma', 'PIH', 'blackhead', 'cyst', 'freckles', 'nodule', 'papule', 'pustule', 'skin-pore', 'whitehead', 'wrinkle']
"""

with open("/content/skin_dataset/data.yaml", "w") as f:
    f.write(yaml_content)

print("✅ data.yaml updated successfully!")
# Out:
# ✅ data.yaml updated successfully!

# %%
# %cd /content/yolov5

# !python train.py --img 640 --batch 16 --epochs 20 \
--data /content/skin_dataset/data.yaml \
--weights yolov5s.pt \
--name skin_detection \
--project runs/train
# Out:
# /content/yolov5
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-28 16:23:35.160010: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748449415.181057   23440 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748449415.187236   23440 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py \
--weights /content/yolov5/runs/train/skin_detection3/weights/best.pt \
--img 640 \
--conf 0.25 \
--source /content/skin_dataset/valid/images \
--project runs/detect \
--name skin_test \
--exist-ok
# Out:
# detect: weights=['/content/yolov5/runs/train/skin_detection3/weights/best.pt'], source=/content/skin_dataset/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=skin_test, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-419-gcd44191c Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7042489 parameters, 0 gradients, 15.9 GFLOPs
# image 1/398 /content/skin_dataset/valid/images/0000124096_003_20210531100105889_jpg.rf.1c957ccf48124ae164be6fb606fade8f.jpg: 448x640 1 Dark Circle, 1 freckles, 28.5ms
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bd276e0b-7154-432b-8e69-47a71cc5649f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd276e0b-7154-432b-8e69-47a71cc5649f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17483, done.
# remote: Total 17483 (delta 0), reused 0 (delta 0), pack-reused 17483 (from 1)
# Receiving objects: 100% (17483/17483), 16.58 MiB | 23.49 MiB/s, done.
# Resolving deltas: 100% (11991/11991), done.

# %%
# !pip install ultralytics

# %%
# !mv best.pt yolov5/
# %cd yolov5
# !python detect.py --weights best.pt --source /content/skin_dataset/valid/images --conf 0.25 --name skin_test
# Out:
# mv: cannot move 'best.pt' to 'yolov5/': Not a directory
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5
# detect: weights=['best.pt'], source=/content/skin_dataset/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=skin_test, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-419-gcd44191c Python-3.11.12 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7042489 parameters, 0 gradients, 15.9 GFLOPs
# image 1/398 /content/skin_dataset/valid/images/0000124096_003_20210531100105889_jpg.rf.1c957ccf48124ae164be6fb606fade8f.jpg: 448x640 1 Dark Circle, 1 freckles, 339.1ms
# ...
